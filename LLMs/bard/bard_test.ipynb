# %%
# !pip install bardapi
# Out:
# ^C
# Collecting bardapi
#   Downloading bardapi-0.1.38-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: httpx>=0.20.0 in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from httpx[http2]>=0.20.0->bardapi) (0.25.2)
# Requirement already satisfied: requests in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from bardapi) (2.31.0)
# Collecting deep-translator (from bardapi)
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: colorama in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from bardapi) (0.4.6)
# Collecting google-cloud-translate (from bardapi)
#   Downloading google_cloud_translate-3.13.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting browser-cookie3 (from bardapi)
#   Downloading browser_cookie3-0.19.1-py3-none-any.whl.metadata (632 bytes)
# Collecting langdetect (from bardapi)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -------------- ---------------------- 389.1/981.5 kB 12.2 MB/s eta 0:00:01
#      -------------------------------- ---- 849.9/981.5 kB 10.8 MB/s eta 0:00:01
#      -------------------------------------- 981.5/981.5 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: anyio in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->bardapi) (3.7.1)
# Requirement already satisfied: certifi in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->bardapi) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->bardapi) (1.0.2)
# Requirement already satisfied: idna in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->bardapi) (3.6)
# Requirement already satisfied: sniffio in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->bardapi) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->bardapi) (0.14.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->bardapi)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#      ---------------------------------------- 57.5/57.5 kB 3.1 MB/s eta 0:00:00
# Collecting lz4 (from browser-cookie3->bardapi)
#   Downloading lz4-4.3.3-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting pycryptodomex (from browser-cookie3->bardapi)
#   Downloading pycryptodomex-3.19.1-cp35-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting beautifulsoup4<5.0.0,>=4.9.1 (from deep-translator->bardapi)
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ---------------------------------------- 0.0/143.0 kB ? eta -:--:--
#      -------------------------------------- 143.0/143.0 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from requests->bardapi) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from requests->bardapi) (2.1.0)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi)
#   Downloading google_api_core-2.15.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-core<3.0.0dev,>=1.4.4 (from google-cloud-translate->bardapi)
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-cloud-translate->bardapi)
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from google-cloud-translate->bardapi) (4.21.12)
# Requirement already satisfied: six in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from langdetect->bardapi) (1.16.0)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->bardapi)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi)
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi)
#   Downloading google_auth-2.25.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi)
#   Downloading grpcio-1.60.0-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi)
#   Downloading grpcio_status-1.60.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.20.0->bardapi)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.20.0->bardapi)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: exceptiongroup in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->bardapi) (1.2.0)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi)
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi)
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ---------------------------------------- 0.0/181.3 kB ? eta -:--:--
#      -------------------------------------- 181.3/181.3 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\yeonsik\miniforge3\envs\mapia\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-translate->bardapi) (0.5.1)
# Downloading bardapi-0.1.38-py3-none-any.whl (39 kB)
# Downloading browser_cookie3-0.19.1-py3-none-any.whl (14 kB)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ---------------------------------------- 0.0/42.3 kB ? eta -:--:--
#    ---------------------------------------- 42.3/42.3 kB 2.1 MB/s eta 0:00:00
# Downloading google_cloud_translate-3.13.0-py2.py3-none-any.whl (127 kB)
#    ---------------------------------------- 0.0/128.0 kB ? eta -:--:--
#    ---------------------------------------- 128.0/128.0 kB 7.4 MB/s eta 0:00:00
# Downloading google_api_core-2.15.0-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/122.0 kB ? eta -:--:--
#    ---------------------------------------- 122.0/122.0 kB 7.0 MB/s eta 0:00:00
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#    ---------------------------------------- 48.8/48.8 kB 2.6 MB/s eta 0:00:00
# Downloading lz4-4.3.3-cp310-cp310-win_amd64.whl (99 kB)
#    ---------------------------------------- 0.0/99.8 kB ? eta -:--:--
#    ---------------------------------------- 99.8/99.8 kB 5.6 MB/s eta 0:00:00
# Downloading pycryptodomex-3.19.1-cp35-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.8 MB 9.6 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.8 MB 10.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.5/1.8 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 10.1 MB/s eta 0:00:00
# Downloading google_auth-2.25.2-py2.py3-none-any.whl (184 kB)
#    ---------------------------------------- 0.0/184.2 kB ? eta -:--:--
#    --------------------------------------- 184.2/184.2 kB 11.6 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ---------------------------------------- 0.0/228.7 kB ? eta -:--:--
#    ---------------------------------------- 228.7/228.7 kB ? eta 0:00:00
# Downloading grpcio-1.60.0-cp310-cp310-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ----------- ---------------------------- 1.1/3.7 MB 22.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.1/3.7 MB 22.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.8/3.7 MB 19.6 MB/s eta 0:00:01
#    -------------------------------------- - 3.6/3.7 MB 19.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 16.9 MB/s eta 0:00:00
# Downloading grpcio_status-1.60.0-py3-none-any.whl (14 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993254 sha256=ad9ae283d0d8310c4fa2156e26cbef61f9fa00159a7f20557e66b8e182c511d2
#   Stored in directory: c:\users\yeonsik\appdata\local\pip\cache\wheels\95\03\7d\59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: soupsieve, pycryptodomex, pyasn1-modules, proto-plus, lz4, langdetect, hyperframe, hpack, grpcio, googleapis-common-protos, cachetools, h2, grpcio-status, google-auth, browser-cookie3, beautifulsoup4, google-api-core, deep-translator, google-cloud-core, google-cloud-translate, bardapi
# Successfully installed bardapi-0.1.38 beautifulsoup4-4.12.2 browser-cookie3-0.19.1 cachetools-5.3.2 deep-translator-1.11.4 google-api-core-2.15.0 google-auth-2.25.2 google-cloud-core-2.4.1 google-cloud-translate-3.13.0 googleapis-common-protos-1.62.0 grpcio-1.60.0 grpcio-status-1.60.0 h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1 langdetect-1.0.9 lz4-4.3.3 proto-plus-1.23.0 pyasn1-modules-0.3.0 pycryptodomex-3.19.1 soupsieve-2.5

# %%
from bard_api import summarizer
 
# 입력 텍스트
input_text = '''
On a sunny day, John went to the park to play baseball with his friends. He hit a home run and everyone cheered.
'''
 
# Bard-API로 입력 텍스트 요약하기
summary = summarizer.summarize(input_text)
 
print(summary)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from bard_api import summarizer
#       3 # 입력 텍스트
#       4 input_text = '''
#       5 On a sunny day, John went to the park to play baseball with his friends. He hit a home run and everyone cheered.
#       6 '''
#
# ModuleNotFoundError: No module named 'bard_api'
